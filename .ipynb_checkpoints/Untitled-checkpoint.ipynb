# %%
import googlemaps
from datetime import datetime
import numpy as np
import pandas as pd

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator

# %%
gmaps = googlemaps.Client(key='AIzaSyChRPbcijpeOUCdai9OSMZAxRELsIInToA')

# %%
data = np.array([])

central = [41.349155, -106.321367]

longitude_range = 0.03
latitude_range = 0.03

coordinate_num = 80 # The maximum lence 

for i in np.linspace(-latitude_range, latitude_range, num=coordinate_num):
    for j in np.linspace(-longitude_range,longitude_range, num=coordinate_num):
        data = np.append(data, [[i,j]])

coordination = data.reshape((coordinate_num*coordinate_num, 2)) + central
coordination_matrix = coordination.reshape(coordinate_num, coordinate_num, 2)
#print(coordination)
print(coordination.shape)
# Out:
# (1600, 2)

# %%
int(coordinate_num/20)**2
# Out:
# 4

# %%
coordination_fragment = coordination.reshape((int(coordinate_num/20)**2,400,2))
coordination_fragment[0].shape
# Out:
# (400, 2)

# %%
hight = np.array([])

for i in range(int(coordinate_num/20)**2):
    print(i)
    hight_list = gmaps.elevation(coordination_fragment[i])
    
    for i in hight_list:
        hight = np.append(hight , i["elevation"])

print(hight.shape)
# Out:
# 0
# 1
# 2
# 3
# (1600,)

# %%
elevation = pd.DataFrame(hight, columns=['elevation'])
coordination = pd.DataFrame(coordination, columns=['latitude', "longitude"])
geo_data = pd.concat([coordination, elevation], axis=1)
geo_data.to_csv('geo_data.csv', index=False)
geo_data
# Out:
#        latitude   longitude    elevation
# 0     41.339155 -106.331367  3502.311279
# 1     41.339155 -106.330854  3507.179688
# 2     41.339155 -106.330341  3505.836670
# 3     41.339155 -106.329829  3469.199463
# 4     41.339155 -106.329316  3426.574951
# 5     41.339155 -106.328803  3400.740234
# 6     41.339155 -106.328290  3376.109375
# 7     41.339155 -106.327777  3329.854492
# 8     41.339155 -106.327264  3292.604248
# 9     41.339155 -106.326752  3268.164062
# 10    41.339155 -106.326239  3254.175049
# 11    41.339155 -106.325726  3248.637695
# 12    41.339155 -106.325213  3246.216553
# 13    41.339155 -106.324700  3245.567139
# 14    41.339155 -106.324188  3224.974609
# 15    41.339155 -106.323675  3228.104492
# 16    41.339155 -106.323162  3239.292969
# 17    41.339155 -106.322649  3239.776855
# 18    41.339155 -106.322136  3238.499756
# 19    41.339155 -106.321623  3233.517822
# 20    41.339155 -106.321111  3217.402832
# 21    41.339155 -106.320598  3215.773682
# 22    41.339155 -106.320085  3218.617920
# 23    41.339155 -106.319572  3217.600342
# 24    41.339155 -106.319059  3217.414062
# 25    41.339155 -106.318546  3217.796631
# 26    41.339155 -106.318034  3219.665283
# 27    41.339155 -106.317521  3229.532959
# 28    41.339155 -106.317008  3234.345947
# 29    41.339155 -106.316495  3231.622803
# ...         ...         ...          ...
# 1570  41.359155 -106.326239  3519.748779
# 1571  41.359155 -106.325726  3532.949219
# 1572  41.359155 -106.325213  3547.885010
# 1573  41.359155 -106.324700  3557.495361
# 1574  41.359155 -106.324188  3570.463379
# 1575  41.359155 -106.323675  3583.347656
# 1576  41.359155 -106.323162  3590.317627
# 1577  41.359155 -106.322649  3602.800049
# 1578  41.359155 -106.322136  3611.638184
# 1579  41.359155 -106.321623  3618.037354
# 1580  41.359155 -106.321111  3626.195068
# 1581  41.359155 -106.320598  3631.843994
# 1582  41.359155 -106.320085  3636.945068
# 1583  41.359155 -106.319572  3636.045166
# 1584  41.359155 -106.319059  3628.027100
# 1585  41.359155 -106.318546  3606.734131
# 1586  41.359155 -106.318034  3585.207520
# 1587  41.359155 -106.317521  3567.714111
# 1588  41.359155 -106.317008  3552.352295
# 1589  41.359155 -106.316495  3544.876953
# 1590  41.359155 -106.315982  3529.203857
# 1591  41.359155 -106.315470  3523.739014
# 1592  41.359155 -106.314957  3510.652832
# 1593  41.359155 -106.314444  3483.224609
# 1594  41.359155 -106.313931  3466.005127
# 1595  41.359155 -106.313418  3453.902832
# 1596  41.359155 -106.312905  3435.278076
# 1597  41.359155 -106.312393  3443.456543
# 1598  41.359155 -106.311880  3443.603271
# 1599  41.359155 -106.311367  3442.229492
#
# [1600 rows x 3 columns]

# %%
X = np.arange(0,elevation.shape[0])
Y = np.arange(0,elevation.shape[1])
X, Y = np.meshgrid(X, Y)

fig = plt.figure()
ax = fig.gca(projection='3d')

# Plot the surface with face colors taken from the array we made.
surf = ax.plot_surface(X, Y, elevation, linewidth=0)
 
plt.show()
